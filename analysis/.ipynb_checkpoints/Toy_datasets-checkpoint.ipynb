# %%
# %matplotlib inline
from sklearn import datasets
import numpy
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-150492a8a7a7> in <module>()
#       3 import numpy
#       4 from matplotlib import pyplot as plt
# ----> 5 from mpl_toolkits.mplot3d import Axes3D
#
# ImportError: No module named mpl_toolkits.mplot3d

# %%
noisy_circles = datasets.make_circles(n_samples=500, factor=.5,
                                      noise=.05)

# %%
plt.scatter(noisy_circles[0][:,0], noisy_circles[0][:,1])

# %%
third_dimension = (noisy_circles[0][:,0])**2+(noisy_circles[0][:,1])**2
plt.scatter(noisy_circles[0][:,0], noisy_circles[0][:,1])

# %%
noisy_circles[0][1:3,0]
# Out:
# array([-0.55761192, -0.04821577])

# %%
noisy_circles[0][1:3,0]**2 + noisy_circles[0][1:3,1]**2
# Out:
# array([ 0.38488712,  0.29432102])

# %%
# Out:
# 0.31091776

# %%
noisy_moons = datasets.make_moons(n_samples=500, noise=.05)

# %%
plt.scatter(noisy_moons[0][200:400,0], noisy_moons[0][200:400,1])

# %%
blobs = datasets.make_blobs(n_samples=500, random_state=32689)

# %%
plt.scatter(blobs[0][:,0], blobs[0][:,1])
